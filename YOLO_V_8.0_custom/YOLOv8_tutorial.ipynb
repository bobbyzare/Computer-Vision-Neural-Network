# %% [markdown]
# .**YOLOv8 is the latest version of the YOLO (You Only Look Once) family of real-time object detection models, developed by Ultralytics. It features a new backbone architecture, improved detection head, and dynamic anchor boxes for better accuracy and speed. Built on PyTorch, it supports object detection, segmentation, and classification, with enhancements for faster training and inference. YOLOv8 is optimized for real-time applications and offers easy integration and customization through the Ultralytics Hub. It achieves higher accuracy and efficiency compared to previous YOLO versions**

# %%
# !nvidia-smi
# Out:
# Fri Sep  6 12:04:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

# %% [markdown]
# # **1. Detection**

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Ultralytics YOLOv8.2.88 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 146.4ms
# Speed: 5.8ms preprocess, 146.4ms inference, 1268.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image in BGR format
img = cv2.imread("/content/runs/detect/predict/bus.jpg", cv2.IMREAD_COLOR)

# Convert the image from BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Optional: hide the axes
plt.show()

# %% [markdown]
# # **2. Segmentation**

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# Ultralytics YOLOv8.2.88 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 266.3ms
# Speed: 4.9ms preprocess, 266.3ms inference, 1572.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image in BGR format
img = cv2.imread("/content/runs/segment/predict/bus.jpg", cv2.IMREAD_COLOR)

# Convert the image from BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Optional: hide the axes
plt.show()

# %% [markdown]
# #  **3. Claasification**

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# Ultralytics YOLOv8.2.88 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 224x224 minibus 0.50, police_van 0.29, trolleybus 0.05, golfcart 0.02, jinrikisha 0.02, 2.7ms
# Speed: 11.0ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image in BGR format
img = cv2.imread("/content/runs/classify/predict/bus.jpg", cv2.IMREAD_COLOR)

# Convert the image from BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Optional: hide the axes
plt.show()
